# %% [markdown]
# # YOLO11

# %% [markdown]
# ## yolov11_final_dataset_2cl_23_best - p202_p205_p206

# %%
import fiftyone as fo

dataset = fo.load_dataset('yolo11_final_dataset_2cl_best_p202_p205_p206')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_yolo11x_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 14:07:58 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |███████████████| 1002/1002 [9.6s elapsed, 0s remaining, 100.3 samples/s]
# 10/09/2024 14:08:07 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [9.6s elapsed, 0s remaining, 100.3 samples/s]
# Performing IoU sweep...
# 10/09/2024 14:08:07 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |███████████████| 1002/1002 [8.8s elapsed, 0s remaining, 99.1 samples/s]
# 10/09/2024 14:08:16 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [8.8s elapsed, 0s remaining, 99.1 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.83      0.73      0.77      3538
#    uncovered       0.76      0.58      0.66      1857
#
#    micro avg       0.81      0.68      0.74      5395
#    macro avg       0.80      0.65      0.72      5395
# weighted avg       0.81      0.68      0.73      5395
#
# TP: 3647
# FP: 863
# FN: 1748

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### augm

# %%
import fiftyone as fo

dataset = fo.load_dataset('yolo11_final_dataset_2cl_best_p202_p205_p206_aug')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_yolo11x_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 14:12:40 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |███████████████| 1002/1002 [11.8s elapsed, 0s remaining, 90.8 samples/s]
# 10/09/2024 14:12:51 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [11.8s elapsed, 0s remaining, 90.8 samples/s]
# Performing IoU sweep...
# 10/09/2024 14:12:51 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |███████████████| 1002/1002 [10.4s elapsed, 0s remaining, 98.2 samples/s]
# 10/09/2024 14:13:02 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [10.4s elapsed, 0s remaining, 98.2 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.79      0.81      0.80      3538
#    uncovered       0.61      0.75      0.67      1857
#
#    micro avg       0.72      0.79      0.75      5395
#    macro avg       0.70      0.78      0.74      5395
# weighted avg       0.73      0.79      0.76      5395
#
# TP: 4251
# FP: 1635
# FN: 1144

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### sahi

# %%
import fiftyone as fo

dataset = fo.load_dataset('yolo11_final_dataset_2cl_best_p202_p205_p206_sahi')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_yolo11x_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 20:58:38 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |███████████████| 1002/1002 [11.3s elapsed, 0s remaining, 94.6 samples/s]
# 10/09/2024 20:58:49 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [11.3s elapsed, 0s remaining, 94.6 samples/s]
# Performing IoU sweep...
# 10/09/2024 20:58:49 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |███████████████| 1002/1002 [10.8s elapsed, 0s remaining, 94.9 samples/s]
# 10/09/2024 20:59:00 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [10.8s elapsed, 0s remaining, 94.9 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.78      0.82      0.80      3538
#    uncovered       0.57      0.68      0.62      1857
#
#    micro avg       0.70      0.77      0.74      5395
#    macro avg       0.68      0.75      0.71      5395
# weighted avg       0.71      0.77      0.74      5395
#
# TP: 4160
# FP: 1764
# FN: 1235

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### sahi conf 0.4

# %%
import fiftyone as fo

dataset = fo.load_dataset('yolo11_final_dataset_2cl_best_p202_p205_p206_sahi_2')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_yolo11x_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 21:08:00 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |███████████████| 1002/1002 [10.0s elapsed, 0s remaining, 97.4 samples/s]
# 10/09/2024 21:08:10 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [10.0s elapsed, 0s remaining, 97.4 samples/s]
# Performing IoU sweep...
# 10/09/2024 21:08:10 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |███████████████| 1002/1002 [8.7s elapsed, 0s remaining, 102.3 samples/s]
# 10/09/2024 21:08:19 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [8.7s elapsed, 0s remaining, 102.3 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.87      0.70      0.78      3538
#    uncovered       0.74      0.59      0.65      1857
#
#    micro avg       0.83      0.66      0.73      5395
#    macro avg       0.81      0.64      0.72      5395
# weighted avg       0.83      0.66      0.73      5395
#
# TP: 3562
# FP: 747
# FN: 1833

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# #### metrics

# %%
import fiftyone as fo

dataset = fo.load_dataset('yolo11_final_dataset_2cl_best_p202_p205_p206_sahi')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_yolo11x_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 14:20:05 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |███████████████| 1002/1002 [12.1s elapsed, 0s remaining, 86.2 samples/s]
# 10/09/2024 14:20:17 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [12.1s elapsed, 0s remaining, 86.2 samples/s]
# Performing IoU sweep...
# 10/09/2024 14:20:17 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |███████████████| 1002/1002 [10.8s elapsed, 0s remaining, 90.1 samples/s]
# 10/09/2024 14:20:28 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [10.8s elapsed, 0s remaining, 90.1 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.78      0.82      0.80      3538
#    uncovered       0.57      0.68      0.62      1857
#
#    micro avg       0.70      0.77      0.74      5395
#    macro avg       0.68      0.75      0.71      5395
# weighted avg       0.71      0.77      0.74      5395
#
# TP: 4160
# FP: 1764
# FN: 1235

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ## yolov11_final_dataset_2cl_23_best - p201_p206

# %%
import fiftyone as fo

dataset = fo.load_dataset('yolo11_final_dataset_2cl_best_p201_p206_new')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl1.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_yolo11x_conf03_iou015_best",
    gt_field="full_GT_2cl1",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 14:22:12 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |█████████████████| 644/644 [6.7s elapsed, 0s remaining, 99.7 samples/s]
# 10/09/2024 14:22:19 - INFO - eta.core.utils -    100% |█████████████████| 644/644 [6.7s elapsed, 0s remaining, 99.7 samples/s]
# Performing IoU sweep...
# 10/09/2024 14:22:19 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |█████████████████| 644/644 [6.4s elapsed, 0s remaining, 94.6 samples/s]
# 10/09/2024 14:22:25 - INFO - eta.core.utils -    100% |█████████████████| 644/644 [6.4s elapsed, 0s remaining, 94.6 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.81      0.85      0.83      2324
#    uncovered       0.73      0.60      0.66      1215
#
#    micro avg       0.79      0.77      0.78      3539
#    macro avg       0.77      0.73      0.75      3539
# weighted avg       0.78      0.77      0.77      3539
#
# TP: 2708
# FP: 731
# FN: 831

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# # rt-detr

# %% [markdown]
# ## rt_detr_final_dataset_2cl_1_best

# %%
import fiftyone as fo

dataset = fo.load_dataset('rt_detr_final_dataset_2cl_best_p201_p206_1')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_rt_detr_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 14:28:28 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |█████████████████| 644/644 [7.4s elapsed, 0s remaining, 93.6 samples/s]
# 10/09/2024 14:28:35 - INFO - eta.core.utils -    100% |█████████████████| 644/644 [7.4s elapsed, 0s remaining, 93.6 samples/s]
# Performing IoU sweep...
# 10/09/2024 14:28:35 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |█████████████████| 644/644 [7.0s elapsed, 0s remaining, 92.4 samples/s]
# 10/09/2024 14:28:42 - INFO - eta.core.utils -    100% |█████████████████| 644/644 [7.0s elapsed, 0s remaining, 92.4 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.68      0.94      0.79      2324
#    uncovered       0.68      0.45      0.54      1215
#
#    micro avg       0.68      0.77      0.73      3539
#    macro avg       0.68      0.70      0.67      3539
# weighted avg       0.68      0.77      0.71      3539
#
# TP: 2737
# FP: 1268
# FN: 802

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### sahi

# %%
import fiftyone as fo

dataset = fo.load_dataset('rt_detr_final_dataset_2cl_best_p201_p206_sahi_conf05')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_rt_detr_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 15:01:54 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |█████████████████| 644/644 [12.6s elapsed, 0s remaining, 70.3 samples/s]
# 10/09/2024 15:02:07 - INFO - eta.core.utils -    100% |█████████████████| 644/644 [12.6s elapsed, 0s remaining, 70.3 samples/s]
# Performing IoU sweep...
# 10/09/2024 15:02:07 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |█████████████████| 644/644 [11.6s elapsed, 0s remaining, 77.6 samples/s]
# 10/09/2024 15:02:18 - INFO - eta.core.utils -    100% |█████████████████| 644/644 [11.6s elapsed, 0s remaining, 77.6 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.74      0.87      0.80      2324
#    uncovered       0.72      0.56      0.63      1215
#
#    micro avg       0.74      0.76      0.75      3539
#    macro avg       0.73      0.71      0.71      3539
# weighted avg       0.73      0.76      0.74      3539
#
# TP: 2693
# FP: 964
# FN: 846

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ## rt_detr_final_dataset_2cl_best_p202_p205_p206

# %%
import fiftyone as fo

dataset = fo.load_dataset('rt_detr_final_dataset_2cl_best_p202_p205_p206_1')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_rt_detr_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 20:25:11 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |███████████████| 1002/1002 [11.6s elapsed, 0s remaining, 94.2 samples/s]
# 10/09/2024 20:25:22 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [11.6s elapsed, 0s remaining, 94.2 samples/s]
# Performing IoU sweep...
# 10/09/2024 20:25:22 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |███████████████| 1002/1002 [10.9s elapsed, 0s remaining, 94.2 samples/s]
# 10/09/2024 20:25:33 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [10.9s elapsed, 0s remaining, 94.2 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.82      0.69      0.75      3538
#    uncovered       0.49      0.70      0.58      1857
#
#    micro avg       0.66      0.70      0.68      5395
#    macro avg       0.66      0.70      0.66      5395
# weighted avg       0.71      0.70      0.69      5395
#
# TP: 3759
# FP: 1897
# FN: 1636

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### conf 0.5

# %%
import fiftyone as fo

dataset = fo.load_dataset('rt_detr_final_dataset_2cl_best_p202_p205_p206_3')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_rt_detr_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 20:46:46 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |███████████████| 1002/1002 [9.6s elapsed, 0s remaining, 96.4 samples/s]
# 10/09/2024 20:46:56 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [9.6s elapsed, 0s remaining, 96.4 samples/s]
# Performing IoU sweep...
# 10/09/2024 20:46:56 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |███████████████| 1002/1002 [8.6s elapsed, 0s remaining, 106.6 samples/s]
# 10/09/2024 20:47:05 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [8.6s elapsed, 0s remaining, 106.6 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.86      0.62      0.72      3538
#    uncovered       0.61      0.65      0.63      1857
#
#    micro avg       0.75      0.63      0.68      5395
#    macro avg       0.73      0.63      0.67      5395
# weighted avg       0.77      0.63      0.69      5395
#
# TP: 3399
# FP: 1143
# FN: 1996

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### sahi

# %%
import fiftyone as fo

dataset = fo.load_dataset('rt_detr_final_dataset_2cl_best_p202_p205_p206_sahi_1')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("full_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="preds_rt_detr_conf03_iou015_best",
    gt_field="full_GT_2cl",
    eval_key="full_GT_vs_yolo11",
    method="coco",
    compute_mAP=True,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("full_GT_vs_yolo11_tp"))
print("FP: %d" % dataset.sum("full_GT_vs_yolo11_fp"))
print("FN: %d" % dataset.sum("full_GT_vs_yolo11_fn"))
# Out:
# Evaluating detections...
# 10/09/2024 20:34:56 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |███████████████| 1002/1002 [9.8s elapsed, 0s remaining, 102.7 samples/s]
# 10/09/2024 20:35:06 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [9.8s elapsed, 0s remaining, 102.7 samples/s]
# Performing IoU sweep...
# 10/09/2024 20:35:06 - INFO - fiftyone.utils.eval.coco -   Performing IoU sweep...
#  100% |███████████████| 1002/1002 [8.5s elapsed, 0s remaining, 106.6 samples/s]
# 10/09/2024 20:35:14 - INFO - eta.core.utils -    100% |███████████████| 1002/1002 [8.5s elapsed, 0s remaining, 106.6 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.86      0.59      0.70      3538
#    uncovered       0.66      0.62      0.64      1857
#
#    micro avg       0.78      0.60      0.68      5395
#    macro avg       0.76      0.60      0.67      5395
# weighted avg       0.79      0.60      0.68      5395
#
# TP: 3238
# FP: 933
# FN: 2157

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_21260\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()
