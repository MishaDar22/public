# %% [markdown]
# # GT

# %% [markdown]
# ## Ela-1 vs Ela-2

# %%
import fiftyone as fo

dataset = fo.load_dataset('yolo11_final_dataset_2cl_best_p201_p206_conf_0285')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("asia_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="ela_cart_2cl",
    gt_field="ela_pol_2cl",
    eval_key="ela_vs_ela",
    method="coco",
    compute_mAP=False,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("ela_vs_ela_tp"))
print("FP: %d" % dataset.sum("ela_vs_ela_fp"))
print("FN: %d" % dataset.sum("ela_vs_ela_fn"))
# Out:
# Evaluating detections...
# 10/31/2024 11:56:14 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |█████████████████| 644/644 [8.7s elapsed, 0s remaining, 87.8 samples/s]
# 10/31/2024 11:56:22 - INFO - eta.core.utils -    100% |█████████████████| 644/644 [8.7s elapsed, 0s remaining, 87.8 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.86      0.76      0.81      2124
#    uncovered       0.68      0.86      0.76      1211
#
#    micro avg       0.78      0.80      0.79      3335
#    macro avg       0.77      0.81      0.78      3335
# weighted avg       0.80      0.80      0.79      3335
#
# TP: 2661
# FP: 745
# FN: 674

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_11428\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %%
# Example usage
confusion_values = [
    [1620, 412, 92],  # covered
    [127, 1041, 43],    # uncovered
    [127, 79, 0]      # (none)
]

results = calculate_combined_metrics(confusion_values)
print("Combined Confusion Matrix:\n", results["confusion_matrix"])
print(f"Precision: {results['precision']:.2f}")
print(f"Recall: {results['recall']:.2f}")
print(f"F1 Score: {results['f1_score']:.2f}")
# Out:
# Combined Confusion Matrix:
#  [[   0  206]
#  [ 135 3200]]
# Precision: 0.94
# Recall: 0.96
# F1 Score: 0.95

# %% [markdown]
# ## Asia-1 vs Asia-2

# %%
import fiftyone as fo

dataset = fo.load_dataset('yolo11_final_dataset_2cl_best_p201_p206_conf_0285')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("asia_GT_2cl.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="asia_cart_2cl",
    gt_field="asia_pol_2cl",
    eval_key="asia_vs_asia",
    method="coco",
    compute_mAP=False,
    iou=0.15,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("asia_vs_asia_tp"))
print("FP: %d" % dataset.sum("asia_vs_asia_fp"))
print("FN: %d" % dataset.sum("asia_vs_asia_fn"))
# Out:
# Evaluating detections...
# 10/31/2024 11:59:44 - INFO - fiftyone.utils.eval.detection -   Evaluating detections...
#  100% |█████████████████| 644/644 [8.4s elapsed, 0s remaining, 87.1 samples/s]
# 10/31/2024 11:59:52 - INFO - eta.core.utils -    100% |█████████████████| 644/644 [8.4s elapsed, 0s remaining, 87.1 samples/s]
#               precision    recall  f1-score   support
#
#      covered       0.91      0.94      0.92      2881
#    uncovered       0.81      0.71      0.75       583
#
#    micro avg       0.90      0.90      0.90      3464
#    macro avg       0.86      0.82      0.84      3464
# weighted avg       0.89      0.90      0.89      3464
#
# TP: 3109
# FP: 361
# FN: 355

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_11428\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %%
# Example usage
confusion_values = [
    [2697, 79, 105],  # covered
    [143, 412, 28],    # uncovered
    [120, 19, 0]      # (none)
]

results = calculate_combined_metrics(confusion_values)
print("Combined Confusion Matrix:\n", results["confusion_matrix"])
print(f"Precision: {results['precision']:.2f}")
print(f"Recall: {results['recall']:.2f}")
print(f"F1 Score: {results['f1_score']:.2f}")
# Out:
# Combined Confusion Matrix:
#  [[   0  139]
#  [ 133 3331]]
# Precision: 0.96
# Recall: 0.96
# F1 Score: 0.96
