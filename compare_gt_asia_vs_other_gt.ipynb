# %% [markdown]
# ## Results

# %% [markdown]
# ### Train 1 - Asia/Magda

# %%
import fiftyone as fo

dataset = fo.load_dataset('train_1b')
# Get the 10 most common classes in the dataset
counts = dataset.count_values("object_det_ground_truth.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="object_det_ground_truth",
    gt_field="gt_asia_tr1",
    eval_key="gt_asia_tr1_vs_asia",
    method="coco",
    compute_mAP=False,
    iou=0.25,
    classwise=False
)

# Print a classification report for the top-10 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("gt_asia_tr1_vs_asia_tp"))
print("FP: %d" % dataset.sum("gt_asia_tr1_vs_asia_fp"))
print("FN: %d" % dataset.sum("gt_asia_tr1_vs_asia_fn"))
# Out:
# Evaluating detections...
#  100% |█████████████████| 244/244 [15.0s elapsed, 0s remaining, 16.1 samples/s]
#                 precision    recall  f1-score   support
#
#        covered       0.92      0.93      0.92      1644
#      uncovered       0.82      0.73      0.77       184
# partly_covered       0.81      0.44      0.57       256
#
#      micro avg       0.90      0.85      0.88      2084
#      macro avg       0.85      0.70      0.75      2084
#   weighted avg       0.90      0.85      0.87      2084
#
# TP: 1768
# FP: 187
# FN: 316

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_42192\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### Train 2 - Magda

# %%
import fiftyone as fo

dataset = fo.load_dataset('train_2b')
counts = dataset.count_values("object_det_ground_truth.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="object_det_ground_truth",
    gt_field="gt_asia_tr2",
    eval_key="gt_magda_tr2_vs_asia",
    method="coco",
    compute_mAP=False,
    iou=0.25,
    classwise=False
)

# Print a classification report for the top-20 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("gt_magda_tr2_vs_asia_tp"))
print("FP: %d" % dataset.sum("gt_magda_tr2_vs_asia_fp"))
print("FN: %d" % dataset.sum("gt_magda_tr2_vs_asia_fn"))
# Out:
# Evaluating detections...
#  100% |█████████████████| 620/620 [41.2s elapsed, 0s remaining, 24.3 samples/s]
#                 precision    recall  f1-score   support
#
#        covered       0.74      0.95      0.83      2768
#      uncovered       0.91      0.76      0.83      1006
# partly_covered       0.83      0.40      0.54      1553
#
#      micro avg       0.78      0.76      0.77      5327
#      macro avg       0.83      0.71      0.73      5327
#   weighted avg       0.80      0.76      0.75      5327
#
# TP: 4030
# FP: 1138
# FN: 1297

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_42192\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### Train 3 - Ela

# %%
import fiftyone as fo

dataset = fo.load_dataset('train_3a')
counts = dataset.count_values("object_det_ground_truth.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="object_det_ground_truth",
    gt_field="gt_asia_tr3",
    eval_key="gt_ela_tr3_vs_asia",
    method="coco",
    compute_mAP=False,
    iou=0.25,
    classwise=False
)

# Print a classification report for the top-20 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("gt_ela_tr3_vs_asia_tp"))
print("FP: %d" % dataset.sum("gt_ela_tr3_vs_asia_fp"))
print("FN: %d" % dataset.sum("gt_ela_tr3_vs_asia_fn"))
# Out:
# Evaluating detections...
#  100% |█████████████████| 641/641 [36.7s elapsed, 0s remaining, 25.5 samples/s]
#                 precision    recall  f1-score   support
#
#        covered       0.78      0.97      0.87      2786
# partly_covered       0.48      0.59      0.53       589
#      uncovered       0.95      0.41      0.57      1398
#
#      micro avg       0.76      0.76      0.76      4773
#      macro avg       0.74      0.65      0.66      4773
#   weighted avg       0.80      0.76      0.74      4773
#
# TP: 3615
# FP: 1142
# FN: 1158

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_42192\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %% [markdown]
# ### Train 4 - Asia

# %%
import fiftyone as fo

dataset = fo.load_dataset('train_4b')
counts = dataset.count_values("object_det_ground_truth.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:3]

# Evaluate the objects in the `predictions` field with respect to the
# objects in the `ground_truth` field
results = dataset.evaluate_detections(
    pred_field="object_det_ground_truth",
    gt_field="gt_asia_tr4",
    eval_key="gt_asia_tr4_vs_asia1",
    method="coco",
    compute_mAP=False,
    iou=0.25,
    classwise=False
)

# Print a classification report for the top-20 classes
results.print_report(classes=classes)

# Print some statistics about the total TP/FP/FN counts
print("TP: %d" % dataset.sum("gt_asia_tr4_vs_asia1_tp"))
print("FP: %d" % dataset.sum("gt_asia_tr4_vs_asia1_fp"))
print("FN: %d" % dataset.sum("gt_asia_tr4_vs_asia1_fn"))
# Out:
# Evaluating detections...
#  100% |█████████████████| 807/807 [51.3s elapsed, 0s remaining, 20.5 samples/s]
#                 precision    recall  f1-score   support
#
#        covered       0.74      0.95      0.83      3771
# partly_covered       0.66      0.37      0.48      1554
#      uncovered       0.97      0.54      0.70      1547
#
#      micro avg       0.76      0.73      0.74      6872
#      macro avg       0.79      0.62      0.67      6872
#   weighted avg       0.78      0.73      0.72      6872
#
# TP: 5008
# FP: 1571
# FN: 1864

# %%
plot = results.plot_confusion_matrix(backend="matplotlib")
plot.show()
# Out:
# C:\Users\MikhailDarakhovich\AppData\Local\Temp\ipykernel_42192\88602896.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()
